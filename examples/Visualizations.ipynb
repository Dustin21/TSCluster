# %%
from Visualizations import *
import pandas as pd
import numpy as np
#%matplotlib inline

# %%
minmax_data_3d = pd.read_csv('outputs/minmax_mapped_3d.csv')
z_data_3d = pd.read_csv('outputs/z_mapped_3d.csv')
minmax_data_2d = pd.read_csv('outputs/minmax_mapped_2d.csv')
z_data_2d = pd.read_csv('outputs/z_mapped_2d.csv')

# %%
labels = [1, 2, 3]
labels = np.random.choice(labels, size=minmax_data_3d.shape[0])

# %%
Visualizations(minmax_data_3d, labels).pairs_plot(plot_name="plots/minmax_pairsplot.png")
Visualizations(z_data_3d, labels).pairs_plot(plot_name="plots/z_pairsplot.png")

Visualizations(z_data_3d, labels).scatter_2d(plot_name="plots/z_jointplot.png")
Visualizations(minmax_data_3d, labels).scatter_2d(plot_name="plots/minmax_jointplot.png")


# Visualizations(minmax_data_3d, labels).pairs_density_plot(plot_name="plots/minmax_densplot.png")
# Visualizations(z_data_3d, labels).pairs_density_plot(plot_name="plots/z_densplot.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6ba349150a90> in <module>()
#       2 Visualizations(z_data_3d, labels).pairs_plot(plot_name="plots/z_pairsplot.png")
#       3
# ----> 4 Visualizations(z_data_3d, labels).scatter_2d(plot_name="plots/z_jointplot.png")
#       5 Visualizations(minmax_data_3d, labels).scatter_2d(plot_name="plots/minmax_jointplot.png")
#       6
#
# C:\Users\dustin.johnson\PycharmProjects\PowerfulInsightEngine\Visualizations.py in scatter_2d(self, plot_name)
#      19         df.columns = ['X1', 'X2', 'X3', 'clusters']
#      20         sns_plot = sns.lmplot(x='X1', y='X2', hue='clusters', data=df, palette="husl",
# ---> 21                                  plot_kws={"s": 1}, vars=["X1", "X2"])
#      22         sns_plot.savefig(plot_name)
#      23
#
# TypeError: lmplot() got an unexpected keyword argument 'plot_kws'

# %%
Visualizations(minmax_data_3d, labels).scatter_3d(plot_name="plots/minmax_3d_scatter.png")
Visualizations(z_data_3d, labels).scatter_3d(plot_name="plots/z_3d_scatter.png")
